# %% [markdown]
# # Big Data Content Analytics - AUEB
#
# ## Regularization Techniques + Batch Normalization
#
# * Lab Assistant: George Perakis
# * Email: gperakis[at]aeub.gr

# %% [markdown]
# ### Batch Normalization
#
# As Pavel said, **Batch Normalization is just another layer**, so you can use it as such to create your desired network architecture.
#
# The general use case is to use BN between the linear and non-linear layers in your network, because it normalizes the input to your activation function, so that you're centered in the linear section of the activation function (such as Sigmoid).
#
# On the other hand studies showed that is better to user BN after the activation function
#
# https://github.com/ducha-aiki/caffenet-benchmark/blob/master/batchnorm.md

# %%
# Read
# https://medium.com/@yongddeng/regression-analysis-lasso-ridge-and-elastic-net-9e65dc61d6d3

# %% [markdown]
# ### Imports

# %%
import numpy as np
import pandas as pd

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense, Activation, Dropout, BatchNormalization
from tensorflow.keras.optimizers import SGD

# used to create mock-up data
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### Create Mock-up dataset

# %%
n_feats = 20

X, y = make_classification(n_samples=100_000,
                           n_features=20,
                           n_informative=3,
                           n_redundant=0,
                           n_classes=2,
                           n_clusters_per_class=2)

pd.DataFrame(X).head()
# Out:
#          0         1         2         3         4         5         6   \
# 0  0.422706 -0.928619 -0.931469 -1.193359  0.775119  0.554363  1.377198
# 1  0.310658 -0.324803  2.608384 -0.440509 -1.696469 -0.810825  1.109524
# 2 -0.208002  1.148461  0.595609 -0.496434 -0.505634  1.640936 -1.983880
# 3  0.040027  0.026475 -0.803201 -0.723728  0.356059 -1.057029  2.083773
# 4  0.438593 -0.602558 -0.181683  1.840942  0.009848  0.349781  0.082011
#
#          7         8         9         10        11        12        13  \
# 0 -0.294622  0.541544 -1.291927  0.509964  0.121498 -1.238209 -0.019992
# 1  1.433438  0.942162  0.549613  0.906007  1.808363  0.477104 -0.764578
# 2  1.258525 -1.142041 -1.308269 -0.416348 -2.076140 -1.379890  0.534480
# 3  0.800775 -0.390684  0.233652 -0.278940 -0.590208 -2.032871  0.577890
# 4 -0.023172 -0.115354  0.331545  0.903524 -0.164517  0.010802  0.543485
#
#          14        15        16        17        18        19
# 0  0.182703 -0.346593 -1.387421 -2.266002  1.312116 -1.386934
# 1 -0.283812 -0.278289 -0.062148  1.068644 -1.911111  1.566330
# 2 -1.769655 -0.932737  0.528220  0.539708 -1.920654  1.723777
# 3 -1.849037  0.775563  1.079880 -0.133958  0.253547  0.709874
# 4  0.763883  0.995917 -0.467456 -0.316042 -1.483854 -0.014194

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25)

# %%
X_train.shape
# Out:
# (75000, 20)

# %%
X_train.shape[0]
# Out:
# 75000

# %% [markdown]
# ### Build Sequential Model

# %%
# instantiate model
model = Sequential()

# we can think of this chunk as the input layer
model.add(Dense(128, input_dim=X_train.shape[1]))

model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.5))

# we can think of this chunk as the hidden layer    
model.add(Dense(64))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))

# we can think of this chunk as the output layer
model.add(Dense(1))
model.add(BatchNormalization())
model.add(Activation('sigmoid'))

# setting up the optimization of our weights 
sgd = SGD(lr=0.1,
          decay=1e-6,
          momentum=0.9,
          nesterov=True)

model.compile(loss='binary_crossentropy',
              optimizer=sgd,
              metrics=['acc'])
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/gradient_descent.py:102: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(SGD, self).__init__(name, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 128)               2688
#
#  batch_normalization (BatchN  (None, 128)              512
#  ormalization)
#
#  activation (Activation)     (None, 128)               0
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  activation_1 (Activation)   (None, 64)                0
#
#  batch_normalization_1 (Batc  (None, 64)               256
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 1)                 65
#
#  batch_normalization_2 (Batc  (None, 1)                4
#  hNormalization)
#
#  activation_2 (Activation)   (None, 1)                 0
#
# =================================================================
# Total params: 11,781
# Trainable params: 11,395
# Non-trainable params: 386
# _________________________________________________________________

# %% [markdown]
# ### Model Fit

# %%
# fitting the model on the data
model.fit(X_train,
          y_train,
          epochs=20,
          batch_size=16,
          validation_split=0.2, 
          verbose = 2)
# Out:
# Epoch 1/20
# 3750/3750 - 9s - loss: 0.3600 - acc: 0.8353 - val_loss: 0.2059 - val_acc: 0.9309 - 9s/epoch - 3ms/step
# Epoch 2/20
# 3750/3750 - 8s - loss: 0.3222 - acc: 0.8567 - val_loss: 0.2046 - val_acc: 0.9278 - 8s/epoch - 2ms/step
# Epoch 3/20
# 3750/3750 - 8s - loss: 0.3148 - acc: 0.8591 - val_loss: 0.1960 - val_acc: 0.9269 - 8s/epoch - 2ms/step
# Epoch 4/20
# 3750/3750 - 8s - loss: 0.3054 - acc: 0.8657 - val_loss: 0.1929 - val_acc: 0.9293 - 8s/epoch - 2ms/step
# Epoch 5/20
# 3750/3750 - 8s - loss: 0.3041 - acc: 0.8670 - val_loss: 0.1850 - val_acc: 0.9360 - 8s/epoch - 2ms/step
# Epoch 6/20
# 3750/3750 - 8s - loss: 0.3022 - acc: 0.8680 - val_loss: 0.2047 - val_acc: 0.9219 - 8s/epoch - 2ms/step
# Epoch 7/20
# 3750/3750 - 8s - loss: 0.2954 - acc: 0.8714 - val_loss: 0.1875 - val_acc: 0.9296 - 8s/epoch - 2ms/step
# Epoch 8/20
# 3750/3750 - 8s - loss: 0.3021 - acc: 0.8688 - val_loss: 0.2075 - val_acc: 0.9173 - 8s/epoch - 2ms/step
# Epoch 9/20
# 3750/3750 - 8s - loss: 0.2975 - acc: 0.8726 - val_loss: 0.1836 - val_acc: 0.9307 - 8s/epoch - 2ms/step
# Epoch 10/20
# 3750/3750 - 9s - loss: 0.2935 - acc: 0.8743 - val_loss: 0.2046 - val_acc: 0.9193 - 9s/epoch - 2ms/step
# Epoch 11/20
# 3750/3750 - 8s - loss: 0.2968 - acc: 0.8733 - val_loss: 0.1883 - val_acc: 0.9305 - 8s/epoch - 2ms/step
# Epoch 12/20
# 3750/3750 - 8s - loss: 0.2911 - acc: 0.8761 - val_loss: 0.2012 - val_acc: 0.9291 - 8s/epoch - 2ms/step
# Epoch 13/20
# 3750/3750 - 7s - loss: 0.2938 - acc: 0.8735 - val_loss: 0.1886 - val_acc: 0.9333 - 7s/epoch - 2ms/step
# Epoch 14/20
# 3750/3750 - 8s - loss: 0.2938 - acc: 0.8746 - val_loss: 0.1978 - val_acc: 0.9251 - 8s/epoch - 2ms/step
# Epoch 15/20
# 3750/3750 - 7s - loss: 0.2925 - acc: 0.8750 - val_loss: 0.1960 - val_acc: 0.9329 - 7s/epoch - 2ms/step
# Epoch 16/20
# 3750/3750 - 7s - loss: 0.2870 - acc: 0.8778 - val_loss: 0.1854 - val_acc: 0.9335 - 7s/epoch - 2ms/step
# Epoch 17/20
# 3750/3750 - 8s - loss: 0.2904 - acc: 0.8763 - val_loss: 0.1854 - val_acc: 0.9330 - 8s/epoch - 2ms/step
# Epoch 18/20
# 3750/3750 - 7s - loss: 0.2954 - acc: 0.8741 - val_loss: 0.1860 - val_acc: 0.9368 - 7s/epoch - 2ms/step
# Epoch 19/20
# 3750/3750 - 8s - loss: 0.2907 - acc: 0.8760 - val_loss: 0.1988 - val_acc: 0.9217 - 8s/epoch - 2ms/step
# Epoch 20/20
# 3750/3750 - 8s - loss: 0.2922 - acc: 0.8750 - val_loss: 0.1850 - val_acc: 0.9363 - 8s/epoch - 2ms/step

# %%
# Great article in Regularization Techniques:
# https://theaisummer.com/regularization/
