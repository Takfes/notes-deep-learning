# %% [markdown]
# # Big Data Content Analytics - AUEB
#
# ## Text Generation using RNNs
#
# * Lab Assistant: George Perakis
# * Email: gperakis[at]aeub.gr | perakisgeorgios[at]gmail.com

# %% [markdown]
# ### Importing Modules

# %%
from __future__ import print_function

import random
import sys
from typing import List, Tuple

import numpy as np
from more_itertools import windowed
from tensorflow.python.keras.callbacks import ModelCheckpoint
from tensorflow.python.keras.layers import LSTM, Dense, Dropout
from tensorflow.python.keras.models import Sequential
from tensorflow.python.keras.utils.data_utils import get_file
from tqdm import tqdm

# %% [markdown]
# ### Text Generator Class

# %%
class TextGenerator:
    """
    Example script to generate text from Nietzsche's writings.
    
    At least 20 epochs are required before the generated text starts sounding 
    coherent.

    It is recommended to run this script on GPU, as recurrent networks are 
    quite computationally intensive.
    
    If you try this script on new data, make sure your corpus
    has at least ~100k characters. ~1M is better.
    """

    def __init__(self, text_url: str = None, verbose: int = 0):
        """
        
        :param text_url: 
        :param verbose: 
        """
        if text_url is None:
            text_url = "https://s3.amazonaws.com/text-datasets/nietzsche.txt"

        assert isinstance(text_url, str)
        assert isinstance(verbose, int)

        self.verbose = verbose
        self.fname = text_url.split('/')[-1]
        self.text_url = text_url

        self.model = None

        self.characters = set()
        self.char2index = dict()
        self.index2char = dict()
        self.sentences = list()
        self.next_characters = list()

        self.max_len = None
        self.step = None

        self.text = None

    def get_data(self):
        """

        :return:
        """
        path = get_file(fname=self.fname, origin=self.text_url)

        text = open(path).read().lower()

        if self.verbose > 0:
            print(f'Corpus Length: {len(text)}')
            print('--------------------------------------------')
            print('Text snapshot')
            print(text[:150])
            print('--------------------------------------------')

        self.text = text

        return text

    def prepare_data(self,
                     text,
                     max_len: int = 40,
                     step: int = 3):
        """
        # cuts the text in semi-redundant sequences of max_len characters

        :param text:
        :param max_len:
        :param step:
        :return:
        """
        chars = set(text)
        print('total chars:', len(chars))

        char2index = dict((c, i) for i, c in enumerate(chars))
        index2char = dict((i, c) for i, c in enumerate(chars))

        sentences, next_chars = list(), list()

        for w in tqdm(windowed(seq=text, n=(max_len + 1), step=step)):
            sent = ''.join(w[:-1])
            next_char = w[-1]

            if next_char:
                sentences.append(sent)
                next_chars.append(next_char)

        if self.verbose > 0:
            print(f'Number of extracted Sequences: {len(sentences)}')
            print(f'Number of extracted next characters: {len(next_chars)}')
            print(f'Number of characters: {len(chars)}')
            print(f'Length of Char2Index: {len(char2index)}')
            print(f'Length of Index2Char: {len(index2char)}')

        self.characters = chars
        self.char2index = char2index
        self.index2char = index2char
        self.sentences = sentences
        self.next_characters = next_chars
        self.max_len = max_len
        self.step = step

    def vectorize_inputs(
            self, sentences: List[str],
            next_chars: List[str]) -> Tuple[np.ndarray, np.ndarray]:
        """

        :param sentences:
        :param next_chars:
        :return:
        """
        if self.verbose > 0:
            print('Vectorizing inputs...')

        X = np.zeros((len(sentences), self.max_len, len(self.characters)),
                     dtype=np.bool)

        y = np.zeros((len(sentences), len(self.characters)), dtype=np.bool)

        for i, sentence in enumerate(sentences):
            for t, char in enumerate(sentence):
                X[i, t, self.char2index[char]] = 1

            try:
                y[i, self.char2index[next_chars[i]]] = 1

            except:
                print(i, next_chars[i])
                print()
                raise Exception()

        if self.verbose > 0:
            print(f'X shape: {X.shape}')
            print(f'y shape: {y.shape}')

        return X, y

    @staticmethod
    def sample(a: np.ndarray, temperature: float = 1.0) -> np.ndarray:
        """

        :param a:
        :param temperature:
        :return:
        """
        # helper function to sample an index from a probability array
        a = np.log(a) / temperature
        a = np.exp(a) / np.sum(np.exp(a))

        return np.argmax(np.random.multinomial(1, a, 1))

    def build_model(self, lstm_size: int = 10, dr: float = 0.0) -> Sequential:
        """

        :param lstm_size:
        :param dr:
        :return:
        """
        # build the model: 2 stacked LSTM

        if self.verbose > 0:
            print('Build model...')

        model = Sequential()

        model.add(LSTM(lstm_size,
                       return_sequences=True,
                       input_shape=(self.max_len, len(self.characters)),
                       name='lstm_layer_1'))

        model.add(Dropout(dr, name='dropout_layer_1'))

        model.add(LSTM(lstm_size,
                       return_sequences=False,
                       name='lstm_layer_2'))

        model.add(Dropout(dr, name='dropout_layer_2'))

        model.add(Dense(len(self.characters),
                        name='output_layer',
                        activation='softmax'))

        model.compile(loss='categorical_crossentropy',
                      optimizer='adam')

        self.model = model

        print(model.summary())

        return model

    def fit_model(self,
                  X,
                  y,
                  n_repeat=10,
                  bs: int = 128,
                  epochs: int = 100,
                  diversity_list=None,
                  run_examples: bool = True):
        """
        
        :param X: 
        :param y: 
        :param n_repeat: 
        :param bs: 
        :param epochs: 
        :param diversity_list: 
        :param run_examples: 
        :return: 
        """

        # train the model, output generated text after each iteration
        if diversity_list is None:
            diversity_list = [0.2, 0.5, 1.0, 1.2]

        fpath = 'text_generator.h5'

        for iteration in range(1, n_repeat + 1):
            print()
            print('-' * 50)
            print('Iteration', iteration)

            md = ModelCheckpoint(filepath=fpath, monitor='loss', verbose=1,
                                 save_best_only=True)

            self.model.fit(X, y, batch_size=bs, epochs=epochs, verbose=2,
                           callbacks=[md])

            if run_examples:

                start_index = random.randint(0,
                                             len(self.text) - self.max_len - 1)
                #
                for diversity in diversity_list:
                    print()
                    print(f'----- Diversity: {diversity}')
                    #
                    generated_text = ''
                    sentence = self.text[
                               start_index: start_index + self.max_len]

                    generated_text += sentence

                    print(
                        f'----- Generating with seed: ""{sentence}"" ')

                    sys.stdout.write(generated_text)

                    #
                    for i in range(150):

                        x = np.zeros((1, self.max_len, len(self.characters)))

                        for t, char in enumerate(sentence):
                            x[0, t, self.char2index[char]] = 1.

                        preds = self.model.predict(x, verbose=0)[0]

                        try:
                            next_index = self.sample(preds, diversity)
                            next_char = self.index2char[next_index]
                        except:
                            next_char = ''

                        generated_text += next_char
                        sentence = sentence[1:] + next_char

                        sys.stdout.write(next_char)
                        sys.stdout.flush()

                    print()

        return self.model

# %%
def run_example(max_len=40, step=3, lstm_size=100, dropout=0.0,
                n_samples=10_000, n_repeat=5, epochs=100, batch_size=512,
                div_list=None, run_examples=True):
    """

    :param max_len:
    :param step:
    :param lstm_size:
    :param dropout:
    :param n_samples:
    :param n_repeat:
    :param epochs:
    :param batch_size:
    :param div_list:
    :param run_examples:
    :return:
    """

    tgo = TextGenerator()

    text = tgo.get_data()

    tgo.prepare_data(text=text, max_len=max_len, step=step)

    X, y = tgo.vectorize_inputs(sentences=tgo.sentences,
                                next_chars=tgo.next_characters)

    if n_samples:
        X = X[:n_samples, :, :]
        y = y[:n_samples, :]

    tgo.build_model(lstm_size=lstm_size, dr=dropout)

    if div_list is None:
        div_list = [0.2, 0.5, 1.0, 1.2]

    tgo.fit_model(X=X, y=y, n_repeat=n_repeat, epochs=epochs,
                  bs=batch_size, diversity_list=div_list,
                  run_examples=run_examples)

    return tgo.model

# %% [markdown]
# ### Run Example

# %%
run_example(max_len=40,
            step=3,
            lstm_size=100,
            dropout=0.0,
            n_samples=10_000,
            epochs=5,
            batch_size=1024,
            div_list=None,
            run_examples=True)
# Out:
# Downloading data from https://s3.amazonaws.com/text-datasets/nietzsche.txt
# 606208/600901 [==============================] - 1s 2us/step
# total chars:
# 63630it [00:00, 636296.06it/s]
# 57
# 200285it [00:00, 646040.02it/s]
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_layer_1 (LSTM)          (None, 40, 100)           63200
# _________________________________________________________________
# dropout_layer_1 (Dropout)    (None, 40, 100)           0
# _________________________________________________________________
# lstm_layer_2 (LSTM)          (None, 100)               80400
# _________________________________________________________________
# dropout_layer_2 (Dropout)    (None, 100)               0
# _________________________________________________________________
# output_layer (Dense)         (None, 57)                5757
# =================================================================
# Total params: 149,357
# Trainable params: 149,357
# Non-trainable params: 0
# _________________________________________________________________
# None
#
# --------------------------------------------------
# Iteration 1
# Epoch 1/5
#
# Epoch 00001: loss improved from inf to 3.94649, saving model to text_generator.h5
# 10/10 - 2s - loss: 3.9465
# Epoch 2/5
#
# Epoch 00002: loss improved from 3.94649 to 3.28231, saving model to text_generator.h5
# 10/10 - 3s - loss: 3.2823
# Epoch 3/5
#
# Epoch 00003: loss improved from 3.28231 to 3.07075, saving model to text_generator.h5
# 10/10 - 2s - loss: 3.0707
# Epoch 4/5
#
# Epoch 00004: loss improved from 3.07075 to 3.03998, saving model to text_generator.h5
# 10/10 - 2s - loss: 3.0400
# Epoch 5/5
#
# Epoch 00005: loss improved from 3.03998 to 3.02795, saving model to text_generator.h5
# 10/10 - 3s - loss: 3.0280
#
# ----- Diversity: 0.2
# ----- Generating with seed: ""ushed voice, as is but seemly: for it ha""
# ushed voice, as is but seemly: for it ha    ee                    e     e o  ot    r     e   e                    s      e   e    s  e        o e
#
# ----- Diversity: 0.5
# ----- Generating with seed: ""ushed voice, as is but seemly: for it ha""
# ushed voice, as is but seemly: for it ha  ee eau nntor hfet  aa  t      or
# neea  t snyt a an      tifhe i  reh a   r eeua  tisstnoh e te er ea aeeeee shathtdsi  t sapth e  er  t er e  mos ae
#
# ----- Diversity: 1.0
# ----- Generating with seed: ""ushed voice, as is but seemly: for it ha""
# ushed voice, as is but seemly: for it haefltnekhd nnkhcw stnoeldohnbfe edmtha
# ferteo h oe;shneiopeet " yd opnkaoihatoiof
# _hoeriopehi o  ër. y gh iat whtme oqopeat im dbherort ad  uaiaitsu
#
# ----- Diversity: 1.2
# ----- Generating with seed: ""ushed voice, as is but seemly: for it ha""
# ushed voice, as is but seemly: for it ha
# dgd latbnrr,rscmi  sf]zee roacaipus teuooah otnr.aor;"lfydeeslmle rmr tst s"as eo u"oncis-eoe,ho rdhuswib tuincsigao ff'
# uftpgpwi rf eht5 gnta?wu au,
#
# --------------------------------------------------
# Iteration 2
# Epoch 1/5
#
# Epoch 00001: loss improved from inf to 3.02572, saving model to text_generator.h5
# 10/10 - 2s - loss: 3.0257
# Epoch 2/5
#
# Epoch 00002: loss improved from 3.02572 to 3.02377, saving model to text_generator.h5
# 10/10 - 2s - loss: 3.0238
# Epoch 3/5
#
# Epoch 00003: loss improved from 3.02377 to 3.02126, saving model to text_generator.h5
# 10/10 - 3s - loss: 3.0213
# Epoch 4/5
#
# Epoch 00004: loss improved from 3.02126 to 3.02023, saving model to text_generator.h5
# 10/10 - 2s - loss: 3.0202
# Epoch 5/5
#
# Epoch 00005: loss improved from 3.02023 to 3.01966, saving model to text_generator.h5
# 10/10 - 2s - loss: 3.0197
#
# ----- Diversity: 0.2
# ----- Generating with seed: ""y wonder if we at last grow distrustful,""
# y wonder if we at last grow distrustful,      i    eo            a      a     e     tt e    e        e  d s t e  e      e  e  e t   et    n
#
# ----- Diversity: 0.5
# ----- Generating with seed: ""y wonder if we at last grow distrustful,""
# y wonder if we at last grow distrustful,  i tete h  e lsitob atte w  toeto tdostit  td toon esn er e elo  ttntosa t  se reiee  eenel  tio a i e peetaee edpir pe e teteeeine eu  y dt tn  e n
#
# ----- Diversity: 1.0
# ----- Generating with seed: ""y wonder if we at last grow distrustful,""
# y wonder if we at last grow distrustful,iaoyeewnaia  s trn  hito hen lefo ti,e"mgghtcei
# nrp ts li ar"e -f ty  iae.a trin.ai ey]tisvut,nwes-ortictdbrxelt ap enosuadspmeeowseo tnaa, r a   tesa
#
# ----- Diversity: 1.2
# ----- Generating with seed: ""y wonder if we at last grow distrustful,""
# y wonder if we at last grow distrustful,ripfydrurwmorrbwisznrwrtwdf othiopyliphbree
# sss i:rlitesi pt
# eand oswaylnidgeu'tagunl y yrwatcg cdeoex ra e to
# ngpmetbodtorhntnahiol  yhtyf)
# melet r[
#
# --------------------------------------------------
# Iteration 3
# Epoch 1/5
#
# Epoch 00001: loss improved from inf to 3.01839, saving model to text_generator.h5
# 10/10 - 2s - loss: 3.0184
# Epoch 2/5
#
# Epoch 00002: loss improved from 3.01839 to 3.01641, saving model to text_generator.h5
# 10/10 - 2s - loss: 3.0164
# Epoch 3/5
#
# Epoch 00003: loss improved from 3.01641 to 3.01557, saving model to text_generator.h5
# 10/10 - 2s - loss: 3.0156
# Epoch 4/5
#
# Epoch 00004: loss improved from 3.01557 to 3.01313, saving model to text_generator.h5
# 10/10 - 2s - loss: 3.0131
# Epoch 5/5
#
# Epoch 00005: loss improved from 3.01313 to 3.01045, saving model to text_generator.h5
# 10/10 - 2s - loss: 3.0105
#
# ----- Diversity: 0.2
# ----- Generating with seed: ""sting,
#
#     sans genie et sans esprit!
#
# ""
# sting,
#
#     sans genie et sans esprit!
#
# e              e e     e e e
#
# ----- Diversity: 0.5
# ----- Generating with seed: ""sting,
#
#     sans genie et sans esprit!
#
# ""
# sting,
#
#     sans genie et sans esprit!
#
# n iheee t ela   d r o i thte nstoe  eu e urueniett  l    ra o   h renw ttoruu i p   hlt et  u ottt e se i
# oeiae ontfo e  t r
# o    n ae  s r ea etn
#
# ----- Diversity: 1.0
# ----- Generating with seed: ""sting,
#
#     sans genie et sans esprit!
#
# ""
# sting,
#
#     sans genie et sans esprit!
#
# o cfu aoiychhirato t  ti, toont dl ohfas rthsbntgshreom)
# auoe ovltes t
# lesneme
# q ennn ntf evaeft
# g l gte clentotir aiuni  eel ane tr i sroiedtlpieto
#
# ----- Diversity: 1.2
# ----- Generating with seed: ""sting,
#
#     sans genie et sans esprit!
#
# ""
# sting,
#
#     sans genie et sans esprit!
#
# o oon  ". ermyhl
# ceshba nshb  coo om
# "wtpeuhsne  deteay l,ar oni i riwtoosti  ntesilw?aseaswdnrlposou ynhiisnsshm"tyeem whtnh
# ce grdn"ci e5mfm?eu yse
#
# --------------------------------------------------
# Iteration 4
# Epoch 1/5
#
# Epoch 00001: loss improved from inf to 3.00830, saving model to text_generator.h5
# 10/10 - 3s - loss: 3.0083
# Epoch 2/5
#
# Epoch 00002: loss improved from 3.00830 to 3.00523, saving model to text_generator.h5
# 10/10 - 2s - loss: 3.0052
# Epoch 3/5
#
# Epoch 00003: loss improved from 3.00523 to 3.00110, saving model to text_generator.h5
# 10/10 - 2s - loss: 3.0011
# Epoch 4/5
#
# Epoch 00004: loss improved from 3.00110 to 2.99508, saving model to text_generator.h5
# 10/10 - 2s - loss: 2.9951
# Epoch 5/5
#
# Epoch 00005: loss improved from 2.99508 to 2.99033, saving model to text_generator.h5
# 10/10 - 2s - loss: 2.9903
#
# ----- Diversity: 0.2
# ----- Generating with seed: ""tions, because they make him see matters""
# tions, because they make him see matters   e   e          e      h eeo  eet      r  ee   e             t
#
# ----- Diversity: 0.5
# ----- Generating with seed: ""tions, because they make him see matters""
# tions, because they make him see mattersuhn ec  s ian
#  aitis  sot ats oo teocat  ahe e  "o  eni oats h aes oth ieiaosieete ial  ieoarn n oywe en a hoyn r tseeemee eru   iao h  e eor  os   e
#
# ----- Diversity: 1.0
# ----- Generating with seed: ""tions, because they make him see matters""
# tions, because they make him see matters n!oertnomee nn  soiaesuorhae e,her aooetittva retii do ihsltine  ch -gotr fere ot wde sattyn irltnonacmbe t iaylthuvthwdut smn ribbknvi  htg n  wo da
#
# ----- Diversity: 1.2
# ----- Generating with seed: ""tions, because they make him see matters""
# tions, because they make him see matters eho uevclipy r to dp toourba" u
#  tou,deeo)t d ,sxi
#  ueneueey?
# aiaosnt u est -hns
# ,cehb htara g detuniklloorerdoofonnftemnm  a"uhe l
# ee -wtes pra,uur
#
# --------------------------------------------------
# Iteration 5
# Epoch 1/5
#
# Epoch 00001: loss improved from inf to 2.98384, saving model to text_generator.h5
# 10/10 - 2s - loss: 2.9838
# Epoch 2/5
#
# Epoch 00002: loss improved from 2.98384 to 2.97543, saving model to text_generator.h5
# 10/10 - 2s - loss: 2.9754
# Epoch 3/5
#
# Epoch 00003: loss improved from 2.97543 to 2.96630, saving model to text_generator.h5
# 10/10 - 2s - loss: 2.9663
# Epoch 4/5
#
# Epoch 00004: loss improved from 2.96630 to 2.95599, saving model to text_generator.h5
# 10/10 - 2s - loss: 2.9560
# Epoch 5/5
#
# Epoch 00005: loss improved from 2.95599 to 2.94108, saving model to text_generator.h5
# 10/10 - 2s - loss: 2.9411
#
# ----- Diversity: 0.2
# ----- Generating with seed: ""ateur pococurante, to use an expression ""
# ateur pococurante, to use an expression        ei ei       h      t          e t          e      e     t                         e          a
#
# ----- Diversity: 0.5
# ----- Generating with seed: ""ateur pococurante, to use an expression ""
# ateur pococurante, to use an expression tra ars m ia ri cies erde oso  t a ee tlhmlrtl et  e en ag att it i  s  y a l hee reessetai l oi ih tuer e cliwon at aode ,t htteihtie t  oit  n  on
#
# ----- Diversity: 1.0
# ----- Generating with seed: ""ateur pococurante, to use an expression ""
# ateur pococurante, to use an expression wyna ali-enmraoltenbs irpnnthrtuw cduasamea hw oguds  hief es ti spe-st   l aacpoeyntas
# t ahrnau ta tputsyed t,smrna,g-mtc
# satuue it etsl tm.ethea as
#
# ----- Diversity: 1.2
# ----- Generating with seed: ""ateur pococurante, to use an expression ""
# ateur pococurante, to use an expression tslet ol ,rsr,a
# ; stc sgd crd  i laarn"
# nr st ! tm wc lsyse niyts sgvre ;yc
# opep -hbytpf,flt rbe,rae
# hcaw hllt torei a!urfeadtlutruenopo
# thot t ltes
